# %% [markdown]
# # Assignment 1
# Write code to get input from user and store in dictionary and then store that dictionary in list. Here is the required input.
#
# [
#     {"name" : "Hamza Ali",
#      "age"  : 25,
#      "work" : "A.I",
#      "skills" : ["python", "tensorflow", "cloud"],
#      "degree" : {"title" : "BS", "major" : "computer Science", "completionDate" : "Jun 2019"},
#      "salary" : 259999
#      },
#      {"name" : "Farooq Aziz",
#      "age"  : 27,
#      "work" : "Cloud Native",
#      "skills" : ["ubuntu", "docker", "kubernetes"],
#      "degree" : {"title" : "MS", "major" : "Software engineer", "completionDate" : "May 2018"},
#      "salary" : 200000
#      },
#      {"name" : "Abu Bakr",
#      "age"  : 30,
#      "work" : "Blockchain",
#      "skills" : ["python", "Cryptography", "Ethereum"],
#      "degree" : {"title" : "BS", "major" : "computer Science", "completionDate" : "May 2019"},
#      "salary" : 300000
#      }
# ]

# %% [markdown]
# # Solution

# %%
# declare an empty list

lst = []

# declare a dictionary with keys only

dic = {
    "name" : "",
    "age" : "",
    "work" : "",
    "skills" : "",
    "degree" : "",
    "salary" : "",
}

usr = int(input("How many users do you want to Enter : "))

for i in range(usr):
    print(f"Enter Data of user {i+1}\n\n")
    name = input("Enter user name : ")
    dic["name"] = name
    age = int(input("Enter user age : "))
    dic["age"] = age
    work = input("Enter user work : ")
    dic["work"] = work
    print("Enter any of user 3 skills : ")
    
    #declare an empty list for skills
    skill = []
    
    for j in range(3):
        usr_skill = input(f"{j+1}---> ")
        skill.append(usr_skill)
    
    dic["skills"] = skill
    
    #declare a dictionary for degree details
    
    deg = {
        "title" : "",
        "major" : "",
        "completion date" : "",
    }
    
    title = input("Enter title of user's degree : ")
    deg["title"] = title
    major = input("Enter user's major : ")
    deg["major"] = major
    cmpl_date = input("Enter completion date of user's degree : ")
    deg["completion date"] = cmpl_date
    
    dic["degree"] = deg
    
    salary = int(input("Enter your salary : "))
    dic["salary"] = salary
    
    lst.append(dic)
    print("\n\n")
    
print(lst)
# Out:
# How many users do you want to Enter : 1
# Enter Data of user 1
#
#
# Enter user name : Usama
# Enter user age : 21
# Enter user work : AI
# Enter any of user 3 skills :
# 1---> Cloud
# 2---> python
# 3---> tensor flow
# Enter title of user's degree : BS
# Enter user's major : CS
# Enter completion date of user's degree : Jan 2020
# Enter your salary : 200000
#
#
#
# [{'name': 'Usama', 'age': 21, 'work': 'AI', 'skills': ['Cloud', 'python', 'tensor flow'], 'degree': {'title': 'BS', 'major': 'CS', 'completion date': 'Jan 2020'}, 'salary': 200000}]

# %% [markdown]
# # Assignment 2
# Take input from user and print table in that range. Suppose user input 5 and 10. Then print table of 5,6,7,8,9,10
#
# And ouput should be as follows.
#
# 1 x 5 = 5
# 2 x 5 = 10
# 3 x 5 = 15
# 4 x 5 = 20
# 5 x 5 = 25
# 6 x 5 = 30
# 7 x 5 = 35
# 8 x 5 = 40
# 9 x 5 = 45
# 10 x 5 = 50
#
# 1 x 6 = 6
# 2 x 6 = 12
# 3 x 6 = 18
# 4 x 6 = 24
# 5 x 6 = 30
# 6 x 6 = 36
# 7 x 6 = 42
# 8 x 6 = 48
# 9 x 6 = 54
# 10 x 6 = 60
#
# 1 x 7 = 7
# 2 x 7 = 14
# 3 x 7 = 21
# 4 x 7 = 28
# 5 x 7 = 35
# 6 x 7 = 42
# 7 x 7 = 49
# 8 x 7 = 56
# 9 x 7 = 63
# 10 x 7 = 70
#
# 1 x 8 = 8
# 2 x 8 = 16
# 3 x 8 = 24
# 4 x 8 = 32
# 5 x 8 = 40
# 6 x 8 = 48
# 7 x 8 = 56
# 8 x 8 = 64
# 9 x 8 = 72
# 10 x 8 = 80
#
# 1 x 9 = 9
# 2 x 9 = 18
# 3 x 9 = 27
# 4 x 9 = 36
# 5 x 9 = 45
# 6 x 9 = 54
# 7 x 9 = 63
# 8 x 9 = 72
# 9 x 9 = 81
# 10 x 9 = 90
#
# 1 x 10 = 10
# 2 x 10 = 20
# 3 x 10 = 30
# 4 x 10 = 40
# 5 x 10 = 50
# 6 x 10 = 60
# 7 x 10 = 70
# 8 x 10 = 80
# 9 x 10 = 90
# 10 x 10 = 100
# And second output should be like
#
# 5 x 1 = 5	  6 x 1 = 6	  7 x 1 = 7	  8 x 1 = 8	   9 x 1 = 9	   10 x 1 = 10
# 5 x 2 = 10	  6 x 2 = 12	  7 x 2 = 14	  8 x 2 = 16	  9 x 2 = 18	  10 x 2 = 20
# 5 x 3 = 15	  6 x 3 = 18	  7 x 3 = 21	  8 x 3 = 24	  9 x 3 = 27	  10 x 3 = 30
# 5 x 4 = 20	  6 x 4 = 24	  7 x 4 = 28	  8 x 4 = 32	  9 x 4 = 36	  10 x 4 = 40
# 5 x 5 = 25	  6 x 5 = 30	  7 x 5 = 35	  8 x 5 = 40	  9 x 5 = 45	  10 x 5 = 50
# 5 x 6 = 30	  6 x 6 = 36	  7 x 6 = 42	  8 x 6 = 48	  9 x 6 = 54	  10 x 6 = 60
# 5 x 7 = 35	  6 x 7 = 42	  7 x 7 = 49	  8 x 7 = 56	  9 x 7 = 63	  10 x 7 = 70
# 5 x 8 = 40	  6 x 8 = 48	  7 x 8 = 56	  8 x 8 = 64	  9 x 8 = 72	  10 x 8 = 80
# 5 x 9 = 45	  6 x 9 = 54	  7 x 9 = 63	  8 x 9 = 72	  9 x 9 = 81	  10 x 9 = 90
# 5 x 10 = 50	  6 x 10 = 60	  7 x 10 = 70	  8 x 10 = 80	  9 x 10 = 90	  10 x 10 = 100

# %% [markdown]
# # Solution

# %%
#Taking input from user

start_point = int(input("Enter Number of strating table : "))
end_point = int(input("Enter Number of ending table : "))

for i in range(start_point, end_point+1):
    
    for j in range(1, 11):
        print(f"{j} * {i} = {j*i}")
    print("\n\n")
    
end = "\t\t"    
for i in range(1, 11):

    for j in range(start_point, end_point+1):
        print(f"{j} * {i} = {j*i}", end="\t")
    print(end ="\n")
# Out:
# Enter Number of strating table : 2
# Enter Number of ending table : 8
# 1 * 2 = 2
# 2 * 2 = 4
# 3 * 2 = 6
# 4 * 2 = 8
# 5 * 2 = 10
# 6 * 2 = 12
# 7 * 2 = 14
# 8 * 2 = 16
# 9 * 2 = 18
# 10 * 2 = 20
#
#
#
# 1 * 3 = 3
# 2 * 3 = 6
# 3 * 3 = 9
# 4 * 3 = 12
# 5 * 3 = 15
# 6 * 3 = 18
# 7 * 3 = 21
# 8 * 3 = 24
# 9 * 3 = 27
# 10 * 3 = 30
#
#
#
# 1 * 4 = 4
# 2 * 4 = 8
# 3 * 4 = 12
# 4 * 4 = 16
# 5 * 4 = 20
# 6 * 4 = 24
# 7 * 4 = 28
# 8 * 4 = 32
# 9 * 4 = 36
# 10 * 4 = 40
#
#
#
# 1 * 5 = 5
# 2 * 5 = 10
# 3 * 5 = 15
# 4 * 5 = 20
# 5 * 5 = 25
# 6 * 5 = 30
# 7 * 5 = 35
# 8 * 5 = 40
# 9 * 5 = 45
# 10 * 5 = 50
#
#
#
# 1 * 6 = 6
# 2 * 6 = 12
# 3 * 6 = 18
# 4 * 6 = 24
# 5 * 6 = 30
# 6 * 6 = 36
# 7 * 6 = 42
# 8 * 6 = 48
# 9 * 6 = 54
# 10 * 6 = 60
#
#
#
# 1 * 7 = 7
# 2 * 7 = 14
# 3 * 7 = 21
# 4 * 7 = 28
# 5 * 7 = 35
# 6 * 7 = 42
# 7 * 7 = 49
# 8 * 7 = 56
# 9 * 7 = 63
# 10 * 7 = 70
#
#
#
# 1 * 8 = 8
# 2 * 8 = 16
# 3 * 8 = 24
# 4 * 8 = 32
# 5 * 8 = 40
# 6 * 8 = 48
# 7 * 8 = 56
# 8 * 8 = 64
# 9 * 8 = 72
# 10 * 8 = 80
#
#
#
# 2 * 1 = 2	3 * 1 = 3	4 * 1 = 4	5 * 1 = 5	6 * 1 = 6	7 * 1 = 7	8 * 1 = 8
# 2 * 2 = 4	3 * 2 = 6	4 * 2 = 8	5 * 2 = 10	6 * 2 = 12	7 * 2 = 14	8 * 2 = 16
# 2 * 3 = 6	3 * 3 = 9	4 * 3 = 12	5 * 3 = 15	6 * 3 = 18	7 * 3 = 21	8 * 3 = 24
# 2 * 4 = 8	3 * 4 = 12	4 * 4 = 16	5 * 4 = 20	6 * 4 = 24	7 * 4 = 28	8 * 4 = 32
# 2 * 5 = 10	3 * 5 = 15	4 * 5 = 20	5 * 5 = 25	6 * 5 = 30	7 * 5 = 35	8 * 5 = 40
# 2 * 6 = 12	3 * 6 = 18	4 * 6 = 24	5 * 6 = 30	6 * 6 = 36	7 * 6 = 42	8 * 6 = 48
# 2 * 7 = 14	3 * 7 = 21	4 * 7 = 28	5 * 7 = 35	6 * 7 = 42	7 * 7 = 49	8 * 7 = 56
# 2 * 8 = 16	3 * 8 = 24	4 * 8 = 32	5 * 8 = 40	6 * 8 = 48	7 * 8 = 56	8 * 8 = 64
# 2 * 9 = 18	3 * 9 = 27	4 * 9 = 36	5 * 9 = 45	6 * 9 = 54	7 * 9 = 63	8 * 9 = 72
# 2 * 10 = 20	3 * 10 = 30	4 * 10 = 40	5 * 10 = 50	6 * 10 = 60	7 * 10 = 70	8 * 10 = 80
